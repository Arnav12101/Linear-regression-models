# %% [markdown]
# # Predicting the quality of wine using pH (Tensorflow)

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("E:/Machine learning/datasets/winequality-red.csv")

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
l1 = df['pH'].tolist()
l2 = df['quality'].tolist()

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %%
model.compile(optimizer="sgd", loss="mean_squared_error")

# %%
x = np.array(l1, dtype=float)
y = np.array(l2, dtype=float)

# %%
model.fit(x,y,epochs=500)
# Out:
# Epoch 1/500
# 50/50 [==============================] - 0s 1ms/step - loss: 0.9591
# Epoch 2/500
# 50/50 [==============================] - 0s 2ms/step - loss: 0.7445
# Epoch 3/500
# 50/50 [==============================] - 0s 2ms/step - loss: 0.7435
# Epoch 4/500
# 50/50 [==============================] - 0s 2ms/step - loss: 0.7415
# Epoch 5/500
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7443
# Epoch 6/500
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7415
# Epoch 7/500
# 50/50 [==============================] - 0s 2ms/step - loss: 0.7414
# Epoch 8/500
# 50/50 [==============================] - 0s 3ms/step - loss: 0.7395
# Epoch 9/500
# 50/50 [==============================] - 0s 2ms/step - loss: 0.7424
# Epoch 10/500
# 50/50 [==============================] - 0s 2ms/step - loss: 0.7396
# Epoch 11/500
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7396
# Epoch 12/500
# ...

# %%
print(model.predict([3.39]))
# Out:
# 1/1 [==============================] - 0s 31ms/step
# [[5.591528]]

# %% [markdown]
# # The value is 5.591528 which is very close to 6.
